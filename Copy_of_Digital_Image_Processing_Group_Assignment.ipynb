# %% [markdown]
# <a href="https://colab.research.google.com/github/it21045776/Digital-Image-Processing-Group-Assignment/blob/IT21045776/Copy_of_Digital_Image_Processing_Group_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Upload a image and preview it** 🔼
#
# ---

# %%
from google.colab import files
from PIL import Image
import IPython.display as display

uploaded_image = None

def upload_image():
    global uploaded_image
    uploaded = files.upload()
    for name, data in uploaded.items():
        uploaded_image = Image.open(name)
        display.display(uploaded_image)
        return uploaded_image

uploaded_image = upload_image()
# Out:
#      <input type="file" id="files-27b7595a-98c9-4a90-a69c-da1614b11b0c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27b7595a-98c9-4a90-a69c-da1614b11b0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **Image Rotation Feature** ↩
#
# ---

# %%
from PIL import Image
import matplotlib.pyplot as plt

if uploaded_image is not None:
    angle = int(input("Enter the rotation angle (in degrees): "))

    # Rotate the image
    rotated_image = uploaded_image.rotate(angle)

    # display
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    axes[0].imshow(uploaded_image)
    axes[0].set_title('Original Image')
    axes[0].axis('off')
    axes[1].imshow(rotated_image)
    axes[1].set_title('Rotated Image')
    axes[1].axis('off')
    plt.show()
else:
    print("No image uploaded. Please run the first code block to upload an image.")
# Out:
# Enter the rotation angle (in degrees): 75

# %% [markdown]
# # **Image Flip Feature** ▶◀
#
# ---

# %%
from PIL import Image
import matplotlib.pyplot as plt

if uploaded_image is not None:
    flip_direction = input("Enter the flipping direction (h for horizontal, v for vertical): ")

    # Flip direction if/else
    if flip_direction == 'h':
        flipped_image = uploaded_image.transpose(Image.FLIP_LEFT_RIGHT)
    elif flip_direction == 'v':
        flipped_image = uploaded_image.transpose(Image.FLIP_TOP_BOTTOM)
    else:
        print("Invalid flipping direction!")

    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    axes[0].imshow(uploaded_image)
    axes[0].set_title('Original Image')
    axes[0].axis('off')
    axes[1].imshow(flipped_image)
    axes[1].set_title('Flipped Image')
    axes[1].axis('off')
    plt.show()
else:
    print("No image uploaded. Please run the first code block to upload an image.")
# Out:
# Enter the flipping direction (h for horizontal, v for vertical): v

# %% [markdown]
# # **Convert to B&W and Grayscale :** ⚪ ⚫
#
# ---

# %%
from PIL import Image
import matplotlib.pyplot as plt

if uploaded_image is not None:
    bw_image = uploaded_image.convert("1")
    grayscale_image = uploaded_image.convert("L")

    # Display
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(uploaded_image)
    axes[0].set_title('Original Image')
    axes[0].axis('off')
    axes[1].imshow(bw_image, cmap='gray')
    axes[1].set_title('Black and White Image')
    axes[1].axis('off')
    axes[2].imshow(grayscale_image, cmap='gray')
    axes[2].set_title('Grayscale Image')
    axes[2].axis('off')
    plt.show()
else:
    print("No image uploaded. Please run the first code block to upload an image.")
